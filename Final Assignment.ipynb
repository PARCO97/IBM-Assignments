# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Paulo Rosales**
#
# Business Analyst

# %% [markdown]
# *I am interested in data science because I love working with data-related projects, and the field is broad enough include many diferent areas of interest for me*

# %% [markdown]
# ### The code below prints the following sentence: "hello world!"

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# > printt('hello world!)
#
# The code above is wrong for the following reasons:
# - The function 'print' is misspelled
# - The text inside the print function lacks a quotation mark at the end
#
#
# [Here](https://www.w3schools.com/python/ref_func_print.asp) is a link for more information about the print function in Python
